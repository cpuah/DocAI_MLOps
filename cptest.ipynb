# %% [markdown]
# ## Setup

# %%
import os

from dotenv import dotenv_values
from azure.identity import DefaultAzureCredential
from modules.app_settings import AppSettings
from modules.model_training_client import ModelTrainingClient
from modules.document_canvas import (DocumentCanvas)
from modules.document_intelligence_label import DocumentIntelligenceLabel
from modules.document_intelligence_result_formatter import DocumentIntelligenceResultFormatter

# %%
working_dir = os.path.abspath('')

# %%
settings = AppSettings(dotenv_values(f"{working_dir}/config.env"))

# %%
azure_credential = DefaultAzureCredential(
    exclude_environment_credential=True,
    exclude_managed_identity_credential=True,
    exclude_shared_token_cache_credential=True,
    exclude_interactive_browser_credential=True,
    exclude_powershell_credential=True,
    exclude_visual_studio_code_credential=False,
    exclude_cli_credential=False
)

# %%
model_training_client = ModelTrainingClient(settings=settings, use_azure_credential=False, azure_credential=azure_credential)

# %% [markdown]
# ## Demo

# %%
    # case 1: 
    #     model_name = 'Contoso'
    #     pdf_file_name = 'invoice-logic-apps-test 2.pdf'

    # case 2:
    #     model_name = 'Contoso'
    #     pdf_file_name = 'invoice_AG42923.pdf'

    # case 3:
    #     model_name = 'Alton'
    #     pdf_file_name = 'invoice_AG42923.pdf'

    # case 4:
    #     model_name = 'Combivan'
    #     pdf_file_name = 'invoice-logic-apps-test 2.pdf'

    # case 5:
    #     model_name = 'Combivan'
    #     pdf_file_name = 'invoice_AG42923.pdf'

    # case 6:
    #     model_name = 'CombivanV2'
    #     pdf_file_name = 'invoice_6.pdf'

demostep = 1

# %% [markdown]
# ### Parameters

# %%
match demostep:
    case 1: 
        model_name = 'Contoso'
        pdf_file_name = 'invoice-logic-apps-test 2.pdf'
    case 2:
        model_name = 'Contoso'
        pdf_file_name = 'invoice_AG42923.pdf'
    case 3:
        model_name = 'Alton'
        pdf_file_name = 'invoice_AG42923.pdf'
    case 4:
        model_name = 'Combivan'
        pdf_file_name = 'invoice-logic-apps-test 2.pdf'
    case 5:
        model_name = 'Combivan'
        pdf_file_name = 'invoice_AG42923.pdf'
    case 6:
        model_name = 'CombivanV2'
        pdf_file_name = 'invoice_6.pdf'

# %%
# The version of the model
initial_model_version = '1.0.0'
initial_model_id = f"{model_name}"
# The name of the PDF file the user is providing.

#pdf_file_name = 'invoice-logic-apps-test 2.pdf'
#pdf_file_name = 'invoice_AG42923.pdf'
#pdf_file_name = 'invoice_6.pdf'

base_file_name = pdf_file_name[:-4]  # Slice the string, excluding the last 4 characters ('.pdf')

# The directory containing the PDF file.
pdf_dir = os.path.join(working_dir, 'pdfs')

# The file path to the PDF file for loading.
pdf_path = os.path.join(pdf_dir, pdf_file_name)

# The file path to where the required JSON result from Azure AI Document Intelligence layout analysis will be stored.
pdf_ocr_path = os.path.join(pdf_dir, f"{pdf_file_name}.ocr.json")

# The file path to where the initial analysis of the user feedback document will be stored.
pdf_feedback_path = os.path.join(pdf_dir, f"{pdf_file_name}.ocr_{initial_model_version}.json")

# The file path to where the required JSON result for Azure AI Document Intelligence labels will be stored after user feedback.
pdf_labels_path = os.path.join(pdf_dir, f"{pdf_file_name}.labels.json")

# The file path to where the required document fields are, based on the original model training data.
document_fields_path = os.path.join(working_dir, 'model_training', 'fields.json')

# %%
# For providing the feedback, the user would perform their analysis using your initial model.
model_training_client.run_layout_analysis(pdf_path, pdf_feedback_path, initial_model_id)
# Out:
# {'status': 'succeeded',
#  'createdDateTime': '2024-09-19T23:47:23Z',
#  'lastUpdatedDateTime': '2024-09-19T23:47:23Z',
#  'analyzeResult': {'apiVersion': '2023-07-31',
#   'modelId': 'Contoso',
#   'content': 'CONTOSO LTD.\nContoso Headquarters 123 456th St New York, NY, 10001\nMicrosoft Corp 123 Other St, Redmond WA, 98052\nBILL TO:\nMicrosoft Finance\n123 Bill St,\nRedmond WA, 98052\nSHIP TO:\nMicrosoft Delivery\n123 Ship St,\nRedmond WA, 98052\nINVOICE\nINVOICE: INV-100 INVOICE DATE: 11/15/2019 DUE DATE: 12/15/2019 CUSTOMER NAME: MICROSOFT CORPORATION SERVICE PERIOD: 10/14/2019 - 11/14/2019 CUSTOMER ID: CID-12345\nSERVICE ADDRESS: Microsoft Services 123 Service St, Redmond WA, 98052\nSALESPERSON\nP.O. NUMBER\nREQUISITIONER\nSHIPPED VIA\nF.O.B. POINT\nTERMS\nPO-3333\nDATE\nITEM CODE\nDESCRIPTION\nQTY\nUM\nPRICE\nTAX\nAMOUNT\n3/4/2021\nA123\nConsulting Services\n2\nhours\n$30.00\n10%\n$60.00\n3/5/2021\nB456\nDocument Fee\n3\n$10.00\n5%\n$30.00\n3/6/2021\nC789\nPrinting Fee\n10\npages\n$1.00\n20%\n$10.00\nSUBTOTAL\n$100.00\nSALES TAX\n$10.00\nTOTAL\n$110.00\nPREVIOUS UNPAID BALANCE\n$500.00\nAMOUNT DUE\n$610.00\nTHANK YOU FOR YOUR BUSINESS!\nREMIT TO:\nContoso Billing\n123 Remit St\nNew York, NY, 10001',
#   'languages': [],
#   'pages': [{'pageNumber': 1,
#     'angle': None,
#     'width': 8.5,
#     'height': 11.0,
#     'unit': 'inch',
#     'lines': [{'content': 'CONTOSO LTD.',
#       'polygon': [0.573,
#        0.6445,
#        2.3303,
#        0.6445,
#        2.3303,
#        0.8928,
#        0.573,
#        0.8928],
#       'spans': [{'offset': 0, 'length': 12}]},
#      {'content': 'Contoso Headquarters',
#       'polygon': [0.5635,
#        1.3989,
#        2.1107,
#        1.3989,
#        2.1107,
#        1.5707,
#        0.5635,
#        1.5707],
#       'spans': [{'offset': 13, 'length': 20}]},
#      {'content': '123 456th St',
#       'polygon': [0.5778,
#        1.6042,
#        1.3944,
#        1.6042,
#        1.3944,
#        1.7665,
#        0.5778,
#        1.7665],
#       'spans': [{'offset': 34, 'length': 12}]},
#      {'content': 'New York, NY, 10001',
#       'polygon': [0.5635,
#        1.8047,
#        1.9913,
#        1.8047,
#        1.9913,
#        1.9766,
#        0.5635,
#        1.9766],
#       'spans': [{'offset': 47, 'length': 19}]},
#      {'content': 'Microsoft Corp',
#       'polygon': [0.573,
#        2.6306,
#        1.6045,
#        2.6306,
#        1.5997,
#        2.7977,
#        0.573,
#        2.7882],
#       'spans': [{'offset': 67, 'length': 14}]},
#      {'content': '123 Other St,',
#       'polygon': [0.5778,
#        2.8264,
#        1.4803,
#        2.8264,
#        1.4756,
#        2.9935,
#        0.5778,
#        2.9887],
#       'spans': [{'offset': 82, 'length': 13}]},
#      {'content': 'Redmond WA, 98052',
#       'polygon': [0.5683,
#        3.0317,
#        2.0152,
#        3.0221,
#        2.0152,
#        3.194,
#        0.5683,
#        3.2036],
#       'spans': [{'offset': 96, 'length': 17}]},
#      {'content': 'BILL TO:',
#       'polygon': [0.5683,
#        3.533,
#        1.1126,
#        3.533,
#        1.1126,
#        3.6762,
#        0.5683,
#        3.6762],
#       'spans': [{'offset': 114, 'length': 8}]},
#      {'content': 'Microsoft Finance',
#       'polygon': [0.5683,
#        3.7478,
#        1.8051,
#        3.7478,
#        1.8051,
#        3.9006,
#        0.5683,
#        3.9006],
#       'spans': [{'offset': 123, 'length': 17}]},
#      {'content': '123 Bill St,',
#       'polygon': [0.5826,
#        3.9531,
#        1.2893,
#        3.9531,
#        1.2893,
#        4.1107,
#        0.5826,
#        4.1107],
#       'spans': [{'offset': 141, 'length': 12}]},
#      {'content': 'Redmond WA, 98052',
#       'polygon': [0.5635,
#        4.1441,
#        2.0152,
#        4.1441,
#        2.0152,
#        4.3112,
#        0.5635,
#        4.3112],
#       'spans': [{'offset': 154, 'length': 17}]},
#      {'content': 'SHIP TO:',
#       'polygon': [3.314, 3.533, 3.911, 3.533, 3.911, 3.681, 3.314, 3.6762],
#       'spans': [{'offset': 172, 'length': 8}]},
#      {'content': 'Microsoft Delivery',
#       'polygon': [3.3093,
#        3.7383,
#        4.589,
#        3.7478,
#        4.589,
#        3.9197,
#        3.3093,
#        3.9054],
#       'spans': [{'offset': 181, 'length': 18}]},
#      {'content': '123 Ship St,',
#       'polygon': [3.3284,
#        3.9531,
#        4.1163,
#        3.9531,
#        4.1163,
#        4.1202,
#        3.3284,
#        4.1155],
#       'spans': [{'offset': 200, 'length': 12}]},
#      {'content': 'Redmond WA, 98052',
#       'polygon': [3.314,
#        4.1393,
#        4.7657,
#        4.1393,
#        4.7657,
#        4.3112,
#        3.314,
#        4.3064],
#       'spans': [{'offset': 213, 'length': 17}]},
#      {'content': 'INVOICE',
#       'polygon': [7.0579,
#        0.5681,
#        8.0129,
#        0.5634,
#        8.0129,
#        0.7782,
#        7.0579,
#        0.783],
#       'spans': [{'offset': 231, 'length': 7}]},
#      {'content': 'INVOICE: INV-100',
#       'polygon': [6.843,
#        1.3893,
#        8.0081,
#        1.3893,
#        8.0081,
#        1.5421,
#        6.843,
#        1.5373],
#       'spans': [{'offset': 239, 'length': 16}]},
#      {'content': 'INVOICE DATE: 11/15/2019',
#       'polygon': [6.2079,
#        1.5946,
#        7.9986,
#        1.5946,
#        7.9986,
#        1.7522,
#        6.2079,
#        1.7474],
#       'spans': [{'offset': 256, 'length': 24}]},
#      {'content': 'DUE DATE: 12/15/2019',
#       'polygon': [6.4705,
#        1.7999,
#        7.9986,
#        1.7999,
#        7.9986,
#        1.9479,
#        6.4705,
#        1.9527],
#       'spans': [{'offset': 281, 'length': 20}]},
#      {'content': 'CUSTOMER NAME: MICROSOFT CORPORATION',
#       'polygon': [4.9329,
#        2.0052,
#        7.9986,
#        2.0052,
#        7.9986,
#        2.1628,
#        4.9329,
#        2.1675],
#       'spans': [{'offset': 302, 'length': 36}]},
#      {'content': 'SERVICE PERIOD: 10/14/2019 - 11/14/2019',
#       'polygon': [5.1478,
#        2.2105,
#        8.0034,
#        2.2105,
#        8.0034,
#        2.3681,
#        5.1478,
#        2.3633],
#       'spans': [{'offset': 339, 'length': 39}]},
#      {'content': 'CUSTOMER ID: CID-12345',
#       'polygon': [6.3081,
#        2.4206,
#        8.0081,
#        2.4206,
#        8.0081,
#        2.5686,
#        6.3081,
#        2.5734],
#       'spans': [{'offset': 379, 'length': 22}]},
#      {'content': 'SERVICE ADDRESS:',
#       'polygon': [6.1792,
#        3.5282,
#        7.4399,
#        3.5234,
#        7.4399,
#        3.6858,
#        6.1792,
#        3.6858],
#       'spans': [{'offset': 402, 'length': 16}]},
#      {'content': 'Microsoft Services',
#       'polygon': [6.1935,
#        3.7431,
#        7.4494,
#        3.7478,
#        7.4494,
#        3.9006,
#        6.1935,
#        3.9006],
#       'spans': [{'offset': 419, 'length': 18}]},
#      {'content': '123 Service St,',
#       'polygon': [6.2079,
#        3.9484,
#        7.1963,
#        3.9531,
#        7.1916,
#        4.1107,
#        6.2079,
#        4.1107],
#       'spans': [{'offset': 438, 'length': 15}]},
#      {'content': 'Redmond WA, 98052',
#       'polygon': [6.1935,
#        4.1441,
#        7.6452,
#        4.1441,
#        7.6452,
#        4.3112,
#        6.1935,
#        4.3112],
#       'spans': [{'offset': 454, 'length': 17}]},
#      {'content': 'SALESPERSON',
#       'polygon': [0.6781,
#        4.6263,
#        1.6236,
#        4.6263,
#        1.6236,
#        4.7695,
#        0.6781,
#        4.7743],
#       'spans': [{'offset': 472, 'length': 11}]},
#      {'content': 'P.O. NUMBER',
#       'polygon': [2.0963,
#        4.6263,
#        3.0275,
#        4.6263,
#        3.0275,
#        4.7695,
#        2.0963,
#        4.7648],
#       'spans': [{'offset': 484, 'length': 11}]},
#      {'content': 'REQUISITIONER',
#       'polygon': [3.4716,
#        4.6215,
#        4.5317,
#        4.6215,
#        4.5317,
#        4.7743,
#        3.4716,
#        4.7743],
#       'spans': [{'offset': 496, 'length': 13}]},
#      {'content': 'SHIPPED VIA',
#       'polygon': [4.7801,
#        4.6311,
#        5.6348,
#        4.6311,
#        5.6348,
#        4.7648,
#        4.7848,
#        4.7648],
#       'spans': [{'offset': 510, 'length': 11}]},
#      {'content': 'F.O.B. POINT',
#       'polygon': [5.8449,
#        4.6263,
#        6.7093,
#        4.6263,
#        6.7093,
#        4.7695,
#        5.8449,
#        4.7695],
#       'spans': [{'offset': 522, 'length': 12}]},
#      {'content': 'TERMS',
#       'polygon': [7.1581,
#        4.6263,
#        7.6309,
#        4.6263,
#        7.6309,
#        4.7648,
#        7.1581,
#        4.7648],
#       'spans': [{'offset': 535, 'length': 5}]},
#      {'content': 'PO-3333',
#       'polygon': [1.8815,
#        4.9032,
#        2.4831,
#        4.9032,
#        2.4831,
#        5.056,
#        1.8815,
#        5.056],
#       'spans': [{'offset': 541, 'length': 7}]},
#      {'content': 'DATE',
#       'polygon': [0.7258,
#        5.4045,
#        1.084,
#        5.3997,
#        1.084,
#        5.5286,
#        0.7258,
#        5.5334],
#       'spans': [{'offset': 549, 'length': 4}]},
#      {'content': 'ITEM CODE',
#       'polygon': [1.3896,
#        5.395,
#        2.1537,
#        5.395,
#        2.1537,
#        5.5334,
#        1.3896,
#        5.5334],
#       'spans': [{'offset': 554, 'length': 9}]},
#      {'content': 'DESCRIPTION',
#       'polygon': [2.827,
#        5.3997,
#        3.7247,
#        5.3997,
#        3.7247,
#        5.5334,
#        2.827,
#        5.5334],
#       'spans': [{'offset': 564, 'length': 11}]},
#      {'content': 'QTY',
#       'polygon': [4.3789,
#        5.4045,
#        4.6654,
#        5.4045,
#        4.6654,
#        5.5382,
#        4.3789,
#        5.5382],
#       'spans': [{'offset': 576, 'length': 3}]},
#      {'content': 'UM',
#       'polygon': [5.0284,
#        5.3997,
#        5.2719,
#        5.4045,
#        5.2719,
#        5.5334,
#        5.0284,
#        5.5334],
#       'spans': [{'offset': 580, 'length': 2}]},
#      {'content': 'PRICE',
#       'polygon': [5.8306,
#        5.3997,
#        6.227,
#        5.3997,
#        6.227,
#        5.5286,
#        5.8306,
#        5.5286],
#       'spans': [{'offset': 583, 'length': 5}]},
#      {'content': 'TAX',
#       'polygon': [6.6997,
#        5.4045,
#        6.9815,
#        5.4045,
#        6.9862,
#        5.5286,
#        6.7045,
#        5.5286],
#       'spans': [{'offset': 589, 'length': 3}]},
#      {'content': 'AMOUNT',
#       'polygon': [7.2632,
#        5.395,
#        7.9174,
#        5.395,
#        7.9174,
#        5.5382,
#        7.2632,
#        5.5382],
#       'spans': [{'offset': 593, 'length': 6}]},
#      {'content': '3/4/2021',
#       'polygon': [0.573,
#        5.6623,
#        1.2225,
#        5.6623,
#        1.2225,
#        5.8342,
#        0.573,
#        5.8342],
#       'spans': [{'offset': 600, 'length': 8}]},
#      {'content': 'A123',
#       'polygon': [1.5854,
#        5.6719,
#        1.9531,
#        5.6719,
#        1.9531,
#        5.8151,
#        1.5902,
#        5.8103],
#       'spans': [{'offset': 609, 'length': 4}]},
#      {'content': 'Consulting Services',
#       'polygon': [2.316, 5.6719, 3.634, 5.6719, 3.634, 5.8294, 2.316, 5.8342],
#       'spans': [{'offset': 614, 'length': 19}]},
#      {'content': '2',
#       'polygon': [4.5843,
#        5.6767,
#        4.6654,
#        5.6767,
#        4.6654,
#        5.8056,
#        4.5843,
#        5.8008],
#       'spans': [{'offset': 634, 'length': 1}]},
#      {'content': 'hours',
#       'polygon': [4.8183,
#        5.6767,
#        5.2146,
#        5.6767,
#        5.2194,
#        5.8151,
#        4.823,
#        5.8151],
#       'spans': [{'offset': 636, 'length': 5}]},
#      {'content': '$30.00',
#       'polygon': [5.9404,
#        5.6623,
#        6.4228,
#        5.6623,
#        6.4275,
#        5.8294,
#        5.9357,
#        5.8294],
#       'spans': [{'offset': 642, 'length': 6}]},
#      {'content': '10%',
#       'polygon': [6.6806,
#        5.6671,
#        7.0053,
#        5.6671,
#        7.0053,
#        5.8247,
#        6.6806,
#        5.8294],
#       'spans': [{'offset': 649, 'length': 3}]},
#      {'content': '$60.00',
#       'polygon': [7.4447,
#        5.6671,
#        7.9174,
#        5.6671,
#        7.9222,
#        5.8294,
#        7.4447,
#        5.8294],
#       'spans': [{'offset': 653, 'length': 6}]},
#      {'content': '3/5/2021',
#       'polygon': [0.573,
#        5.9583,
#        1.2272,
#        5.9583,
#        1.2272,
#        6.1207,
#        0.573,
#        6.1254],
#       'spans': [{'offset': 660, 'length': 8}]},
#      {'content': 'B456',
#       'polygon': [1.5902,
#        5.9727,
#        1.9531,
#        5.9727,
#        1.9531,
#        6.1063,
#        1.5949,
#        6.1111],
#       'spans': [{'offset': 669, 'length': 4}]},
#      {'content': 'Document Fee',
#       'polygon': [2.3208,
#        5.9679,
#        3.3188,
#        5.9679,
#        3.3188,
#        6.1159,
#        2.3208,
#        6.1207],
#       'spans': [{'offset': 674, 'length': 12}]},
#      {'content': '3',
#       'polygon': [4.5843,
#        5.9774,
#        4.6654,
#        5.9774,
#        4.675,
#        6.1016,
#        4.589,
#        6.1016],
#       'spans': [{'offset': 687, 'length': 1}]},
#      {'content': '$10.00',
#       'polygon': [5.9404,
#        5.9631,
#        6.418,
#        5.9583,
#        6.4228,
#        6.1159,
#        5.9404,
#        6.1207],
#       'spans': [{'offset': 689, 'length': 6}]},
#      {'content': '5%',
#       'polygon': [6.7284,
#        5.9774,
#        6.948,
#        5.9679,
#        6.948,
#        6.1063,
#        6.7331,
#        6.1063],
#       'spans': [{'offset': 696, 'length': 2}]},
#      {'content': '$30.00',
#       'polygon': [7.4447,
#        5.9631,
#        7.9222,
#        5.9583,
#        7.9222,
#        6.1159,
#        7.4447,
#        6.1207],
#       'spans': [{'offset': 699, 'length': 6}]},
#      {'content': '3/6/2021',
#       'polygon': [0.573,
#        6.2639,
#        1.2177,
#        6.2591,
#        1.2177,
#        6.4214,
#        0.573,
#        6.4214],
#       'spans': [{'offset': 706, 'length': 8}]},
#      {'content': 'C789',
#       'polygon': [1.5854,
#        6.2687,
#        1.9483,
#        6.2687,
#        1.9483,
#        6.4167,
#        1.5902,
#        6.4119],
#       'spans': [{'offset': 715, 'length': 4}]},
#      {'content': 'Printing Fee',
#       'polygon': [2.316,
#        6.2687,
#        3.1517,
#        6.2687,
#        3.1517,
#        6.4358,
#        2.316,
#        6.4358],
#       'spans': [{'offset': 720, 'length': 12}]},
#      {'content': '10',
#       'polygon': [4.4983,
#        6.2734,
#        4.6702,
#        6.2734,
#        4.675,
#        6.4071,
#        4.5079,
#        6.4119],
#       'spans': [{'offset': 733, 'length': 2}]},
#      {'content': 'pages',
#       'polygon': [4.8087,
#        6.283,
#        5.2337,
#        6.283,
#        5.2337,
#        6.4453,
#        4.8087,
#        6.4453],
#       'spans': [{'offset': 736, 'length': 5}]},
#      {'content': '$1.00',
#       'polygon': [6.0312,
#        6.2591,
#        6.4228,
#        6.2543,
#        6.4275,
#        6.4167,
#        6.0312,
#        6.4214],
#       'spans': [{'offset': 742, 'length': 5}]},
#      {'content': '20%',
#       'polygon': [6.6902,
#        6.2591,
#        7.0006,
#        6.2639,
#        7.0006,
#        6.4262,
#        6.6902,
#        6.4262],
#       'spans': [{'offset': 748, 'length': 3}]},
#      {'content': '$10.00',
#       'polygon': [7.4399,
#        6.2639,
#        7.927,
#        6.2591,
#        7.927,
#        6.4167,
#        7.4399,
#        6.4214],
#       'spans': [{'offset': 752, 'length': 6}]},
#      {'content': 'SUBTOTAL',
#       'polygon': [6.0073,
#        6.8845,
#        6.7427,
#        6.8845,
#        6.7427,
#        7.0421,
#        6.0073,
#        7.0373],
#       'spans': [{'offset': 759, 'length': 8}]},
#      {'content': '$100.00',
#       'polygon': [7.3635,
#        6.8511,
#        7.9317,
#        6.8511,
#        7.9317,
#        7.0135,
#        7.3635,
#        7.0135],
#       'spans': [{'offset': 768, 'length': 7}]},
#      {'content': 'SALES TAX',
#       'polygon': [6.0169,
#        7.1662,
#        6.7379,
#        7.171,
#        6.7379,
#        7.3381,
#        6.0169,
#        7.3381],
#       'spans': [{'offset': 776, 'length': 9}]},
#      {'content': '$10.00',
#       'polygon': [7.4542,
#        7.1567,
#        7.927,
#        7.1519,
#        7.9317,
#        7.3142,
#        7.4542,
#        7.319],
#       'spans': [{'offset': 786, 'length': 6}]},
#      {'content': 'TOTAL',
#       'polygon': [6.2795,
#        7.4861,
#        6.7331,
#        7.4861,
#        6.7331,
#        7.6389,
#        6.2795,
#        7.6293],
#       'spans': [{'offset': 793, 'length': 5}]},
#      {'content': '$110.00',
#       'polygon': [7.3683,
#        7.4527,
#        7.9317,
#        7.4479,
#        7.9317,
#        7.615,
#        7.3683,
#        7.6246],
#       'spans': [{'offset': 799, 'length': 7}]},
#      {'content': 'PREVIOUS UNPAID BALANCE',
#       'polygon': [4.7801,
#        7.7726,
#        6.7331,
#        7.7726,
#        6.7331,
#        7.9349,
#        4.7801,
#        7.9349],
#       'spans': [{'offset': 807, 'length': 23}]},
#      {'content': '$500.00',
#       'polygon': [7.3587,
#        7.7487,
#        7.9413,
#        7.7487,
#        7.9413,
#        7.911,
#        7.3587,
#        7.911],
#       'spans': [{'offset': 831, 'length': 7}]},
#      {'content': 'AMOUNT DUE',
#       'polygon': [5.7494,
#        8.0686,
#        6.7379,
#        8.0686,
#        6.7379,
#        8.2309,
#        5.7494,
#        8.2261],
#       'spans': [{'offset': 839, 'length': 10}]},
#      {'content': '$610.00',
#       'polygon': [7.3587,
#        8.0399,
#        7.9413,
#        8.0399,
#        7.9413,
#        8.2118,
#        7.3587,
#        8.2118],
#       'spans': [{'offset': 850, 'length': 7}]},
#      {'content': 'THANK YOU FOR YOUR BUSINESS!',
#       'polygon': [3.1087,
#        8.5078,
#        5.377,
#        8.5078,
#        5.377,
#        8.6701,
#        3.1087,
#        8.6701],
#       'spans': [{'offset': 858, 'length': 28}]},
#      {'content': 'REMIT TO:',
#       'polygon': [0.5683, 9.138, 1.275, 9.1332, 1.275, 9.2717, 0.5683, 9.2765],
#       'spans': [{'offset': 887, 'length': 9}]},
#      {'content': 'Contoso Billing',
#       'polygon': [0.5683,
#        9.3481,
#        1.5902,
#        9.3481,
#        1.5902,
#        9.5152,
#        0.5683,
#        9.5056],
#       'spans': [{'offset': 897, 'length': 15}]},
#      {'content': '123 Remit St',
#       'polygon': [0.5778,
#        9.5486,
#        1.4469,
#        9.5486,
#        1.4469,
#        9.6966,
#        0.5778,
#        9.6966],
#       'spans': [{'offset': 913, 'length': 12}]},
#      {'content': 'New York, NY, 10001',
#       'polygon': [0.5635,
#        9.7491,
#        1.9961,
#        9.7444,
#        1.9961,
#        9.921,
#        0.5635,
#        9.9258],
#       'spans': [{'offset': 926, 'length': 19}]}],
#     'words': [{'content': 'CONTOSO',
#       'polygon': [0.5778,
#        0.6589,
#        1.6904,
#        0.6541,
#        1.6952,
#        0.8976,
#        0.5778,
#        0.888],
#       'span': {'offset': 0, 'length': 7},
#       'confidence': 0.995},
#      {'content': 'LTD.',
#       'polygon': [1.8146,
#        0.6541,
#        2.3303,
#        0.6493,
#        2.3351,
#        0.8976,
#        1.8194,
#        0.8976],
#       'span': {'offset': 8, 'length': 4},
#       'confidence': 0.986},
#      {'content': 'Contoso',
#       'polygon': [0.573, 1.4036, 1.1222, 1.4036, 1.127, 1.5755, 0.573, 1.5707],
#       'span': {'offset': 13, 'length': 7},
#       'confidence': 0.994},
#      {'content': 'Headquarters',
#       'polygon': [1.1556,
#        1.4036,
#        2.1011,
#        1.3989,
#        2.1059,
#        1.5755,
#        1.1604,
#        1.5755],
#       'span': {'offset': 21, 'length': 12},
#       'confidence': 0.985},
#      {'content': '123',
#       'polygon': [0.5874,
#        1.6042,
#        0.8261,
#        1.6042,
#        0.8261,
#        1.7713,
#        0.5874,
#        1.7713],
#       'span': {'offset': 34, 'length': 3},
#       'confidence': 0.997},
#      {'content': '456th',
#       'polygon': [0.8596,
#        1.6042,
#        1.2177,
#        1.6042,
#        1.2177,
#        1.7713,
#        0.8596,
#        1.7713],
#       'span': {'offset': 38, 'length': 5},
#       'confidence': 0.981},
#      {'content': 'St',
#       'polygon': [1.2463,
#        1.6042,
#        1.3896,
#        1.6042,
#        1.3944,
#        1.7713,
#        1.2511,
#        1.7713],
#       'span': {'offset': 44, 'length': 2},
#       'confidence': 0.995},
#      {'content': 'New',
#       'polygon': [0.5683,
#        1.8142,
#        0.8404,
#        1.8142,
#        0.8452,
#        1.9766,
#        0.573,
#        1.9766],
#       'span': {'offset': 47, 'length': 3},
#       'confidence': 0.996},
#      {'content': 'York,',
#       'polygon': [0.9169,
#        1.8095,
#        1.2559,
#        1.8095,
#        1.2607,
#        1.9766,
#        0.9216,
#        1.9766],
#       'span': {'offset': 51, 'length': 5},
#       'confidence': 0.995},
#      {'content': 'NY,',
#       'polygon': [1.2893,
#        1.8095,
#        1.5424,
#        1.8095,
#        1.5472,
#        1.9766,
#        1.2941,
#        1.9766],
#       'span': {'offset': 57, 'length': 3},
#       'confidence': 0.993},
#      {'content': '10001',
#       'polygon': [1.5758,
#        1.8095,
#        1.9865,
#        1.8095,
#        1.9913,
#        1.9813,
#        1.5806,
#        1.9766],
#       'span': {'offset': 61, 'length': 5},
#       'confidence': 0.995},
#      {'content': 'Microsoft',
#       'polygon': [0.573,
#        2.6306,
#        1.2416,
#        2.6354,
#        1.2416,
#        2.7977,
#        0.573,
#        2.7834],
#       'span': {'offset': 67, 'length': 9},
#       'confidence': 0.993},
#      {'content': 'Corp',
#       'polygon': [1.275,
#        2.6354,
#        1.5806,
#        2.6306,
#        1.5758,
#        2.7977,
#        1.275,
#        2.7977],
#       'span': {'offset': 77, 'length': 4},
#       'confidence': 0.993},
#      {'content': '123',
#       'polygon': [0.5874,
#        2.8359,
#        0.8261,
#        2.8359,
#        0.8309,
#        2.9887,
#        0.5921,
#        2.9839],
#       'span': {'offset': 82, 'length': 3},
#       'confidence': 0.994},
#      {'content': 'Other',
#       'polygon': [0.8596,
#        2.8359,
#        1.2654,
#        2.8312,
#        1.2654,
#        2.9935,
#        0.8596,
#        2.9887],
#       'span': {'offset': 86, 'length': 5},
#       'confidence': 0.995},
#      {'content': 'St,',
#       'polygon': [1.2941,
#        2.8312,
#        1.4756,
#        2.8312,
#        1.4756,
#        2.9935,
#        1.2941,
#        2.9935],
#       'span': {'offset': 92, 'length': 3},
#       'confidence': 0.993},
#      {'content': 'Redmond',
#       'polygon': [0.5683,
#        3.0365,
#        1.2225,
#        3.0317,
#        1.2225,
#        3.2036,
#        0.5683,
#        3.2036],
#       'span': {'offset': 96, 'length': 7},
#       'confidence': 0.995},
#      {'content': 'WA,',
#       'polygon': [1.2654,
#        3.0317,
#        1.5567,
#        3.0317,
#        1.5567,
#        3.2036,
#        1.2654,
#        3.2036],
#       'span': {'offset': 104, 'length': 3},
#       'confidence': 0.995},
#      {'content': '98052',
#       'polygon': [1.5902,
#        3.0317,
#        2.0152,
#        3.0269,
#        2.0152,
#        3.1988,
#        1.5902,
#        3.2036],
#       'span': {'offset': 108, 'length': 5},
#       'confidence': 0.995},
#      {'content': 'BILL',
#       'polygon': [0.5683, 3.5378, 0.8452, 3.5378, 0.85, 3.681, 0.573, 3.6762],
#       'span': {'offset': 114, 'length': 4},
#       'confidence': 0.979},
#      {'content': 'TO:',
#       'polygon': [0.8834,
#        3.5378,
#        1.1126,
#        3.5378,
#        1.1126,
#        3.681,
#        0.8882,
#        3.681],
#       'span': {'offset': 119, 'length': 3},
#       'confidence': 0.995},
#      {'content': 'Microsoft',
#       'polygon': [0.5683,
#        3.7478,
#        1.2368,
#        3.7478,
#        1.2368,
#        3.9006,
#        0.5778,
#        3.9006],
#       'span': {'offset': 123, 'length': 9},
#       'confidence': 0.994},
#      {'content': 'Finance',
#       'polygon': [1.2654,
#        3.7478,
#        1.7907,
#        3.7478,
#        1.7907,
#        3.9054,
#        1.2654,
#        3.9006],
#       'span': {'offset': 133, 'length': 7},
#       'confidence': 0.995},
#      {'content': '123',
#       'polygon': [0.5826,
#        3.9579,
#        0.8261,
#        3.9579,
#        0.8261,
#        4.1155,
#        0.5874,
#        4.1107],
#       'span': {'offset': 141, 'length': 3},
#       'confidence': 0.996},
#      {'content': 'Bill',
#       'polygon': [0.8691,
#        3.9579,
#        1.084,
#        3.9579,
#        1.0792,
#        4.1155,
#        0.8691,
#        4.1155],
#       'span': {'offset': 145, 'length': 4},
#       'confidence': 0.993},
#      {'content': 'St,',
#       'polygon': [1.1126,
#        3.9579,
#        1.2893,
#        3.9579,
#        1.2846,
#        4.1107,
#        1.1126,
#        4.1155],
#       'span': {'offset': 150, 'length': 3},
#       'confidence': 0.995},
#      {'content': 'Redmond',
#       'polygon': [0.5683,
#        4.1489,
#        1.2177,
#        4.1489,
#        1.2225,
#        4.316,
#        0.5683,
#        4.3064],
#       'span': {'offset': 154, 'length': 7},
#       'confidence': 0.995},
#      {'content': 'WA,',
#       'polygon': [1.2607,
#        4.1489,
#        1.5615,
#        4.1489,
#        1.5663,
#        4.316,
#        1.2654,
#        4.316],
#       'span': {'offset': 162, 'length': 3},
#       'confidence': 0.995},
#      {'content': '98052',
#       'polygon': [1.5949,
#        4.1489,
#        2.0152,
#        4.1489,
#        2.0152,
#        4.3112,
#        1.5949,
#        4.316],
#       'span': {'offset': 166, 'length': 5},
#       'confidence': 0.995},
#      {'content': 'SHIP',
#       'polygon': [3.3236,
#        3.5378,
#        3.6197,
#        3.5378,
#        3.6244,
#        3.681,
#        3.3236,
#        3.681],
#       'span': {'offset': 172, 'length': 4},
#       'confidence': 0.986},
#      {'content': 'TO:',
#       'polygon': [3.677, 3.5378, 3.911, 3.5378, 3.911, 3.6858, 3.6817, 3.681],
#       'span': {'offset': 177, 'length': 3},
#       'confidence': 0.995},
#      {'content': 'Microsoft',
#       'polygon': [3.3093,
#        3.7383,
#        3.9874,
#        3.7431,
#        3.9826,
#        3.9149,
#        3.3093,
#        3.9054],
#       'span': {'offset': 181, 'length': 9},
#       'confidence': 0.993},
#      {'content': 'Delivery',
#       'polygon': [4.0208,
#        3.7431,
#        4.5843,
#        3.7478,
#        4.5843,
#        3.9245,
#        4.016,
#        3.9149],
#       'span': {'offset': 191, 'length': 8},
#       'confidence': 0.995},
#      {'content': '123',
#       'polygon': [3.3379,
#        3.9579,
#        3.5767,
#        3.9579,
#        3.5767,
#        4.1202,
#        3.3379,
#        4.1155],
#       'span': {'offset': 200, 'length': 3},
#       'confidence': 0.997},
#      {'content': 'Ship',
#       'polygon': [3.6101,
#        3.9579,
#        3.9014,
#        3.9531,
#        3.8966,
#        4.125,
#        3.6101,
#        4.1202],
#       'span': {'offset': 204, 'length': 4},
#       'confidence': 0.993},
#      {'content': 'St,',
#       'polygon': [3.9444,
#        3.9531,
#        4.1211,
#        3.9531,
#        4.1163,
#        4.125,
#        3.9396,
#        4.125],
#       'span': {'offset': 209, 'length': 3},
#       'confidence': 0.995},
#      {'content': 'Redmond',
#       'polygon': [3.3188,
#        4.1489,
#        3.973,
#        4.1489,
#        3.973,
#        4.3112,
#        3.3188,
#        4.3064],
#       'span': {'offset': 213, 'length': 7},
#       'confidence': 0.995},
#      {'content': 'WA,',
#       'polygon': [4.016, 4.1489, 4.3121, 4.1489, 4.3121, 4.316, 4.016, 4.316],
#       'span': {'offset': 221, 'length': 3},
#       'confidence': 0.995},
#      {'content': '98052',
#       'polygon': [4.3455,
#        4.1489,
#        4.7657,
#        4.1441,
#        4.7657,
#        4.3112,
#        4.3455,
#        4.316],
#       'span': {'offset': 225, 'length': 5},
#       'confidence': 0.995},
#      {'content': 'INVOICE',
#       'polygon': [7.0626,
#        0.5729,
#        7.9843,
#        0.5681,
#        7.989,
#        0.7878,
#        7.0626,
#        0.7878],
#       'span': {'offset': 231, 'length': 7},
#       'confidence': 0.993},
#      {'content': 'INVOICE:',
#       'polygon': [6.843,
#        1.3941,
#        7.4399,
#        1.3989,
#        7.4447,
#        1.5421,
#        6.8478,
#        1.5421],
#       'span': {'offset': 239, 'length': 8},
#       'confidence': 0.992},
#      {'content': 'INV-100',
#       'polygon': [7.4685,
#        1.3989,
#        8.0034,
#        1.3941,
#        8.0034,
#        1.5469,
#        7.4733,
#        1.5421],
#       'span': {'offset': 248, 'length': 7},
#       'confidence': 0.993},
#      {'content': 'INVOICE',
#       'polygon': [6.2079,
#        1.5994,
#        6.757,
#        1.5994,
#        6.757,
#        1.7522,
#        6.2126,
#        1.7426],
#       'span': {'offset': 256, 'length': 7},
#       'confidence': 0.995},
#      {'content': 'DATE:',
#       'polygon': [6.7952, 1.5994, 7.2154, 1.5994, 7.2154, 1.7522, 6.8, 1.7522],
#       'span': {'offset': 264, 'length': 5},
#       'confidence': 0.995},
#      {'content': '11/15/2019',
#       'polygon': [7.2441,
#        1.5994,
#        7.9938,
#        1.5994,
#        7.9938,
#        1.7522,
#        7.2441,
#        1.7522],
#       'span': {'offset': 270, 'length': 10},
#       'confidence': 0.993},
#      {'content': 'DUE',
#       'polygon': [6.4801,
#        1.8095,
#        6.7618,
#        1.8095,
#        6.7618,
#        1.9527,
#        6.4801,
#        1.9527],
#       'span': {'offset': 281, 'length': 3},
#       'confidence': 0.996},
#      {'content': 'DATE:',
#       'polygon': [6.7904,
#        1.8095,
#        7.2107,
#        1.8047,
#        7.2107,
#        1.9527,
#        6.7904,
#        1.9527],
#       'span': {'offset': 285, 'length': 5},
#       'confidence': 0.993},
#      {'content': '12/15/2019',
#       'polygon': [7.2393,
#        1.8047,
#        7.9938,
#        1.7999,
#        7.9938,
#        1.9527,
#        7.2393,
#        1.9527],
#       'span': {'offset': 291, 'length': 10},
#       'confidence': 0.991},
#      {'content': 'CUSTOMER',
#       'polygon': [4.9424, 2.01, 5.6683, 2.01, 5.673, 2.1675, 4.9424, 2.1723],
#       'span': {'offset': 302, 'length': 8},
#       'confidence': 0.995},
#      {'content': 'NAME:',
#       'polygon': [5.7112,
#        2.01,
#        6.1792,
#        2.0148,
#        6.1792,
#        2.1628,
#        5.7112,
#        2.1675],
#       'span': {'offset': 311, 'length': 5},
#       'confidence': 0.993},
#      {'content': 'MICROSOFT',
#       'polygon': [6.2079,
#        2.0148,
#        6.9958,
#        2.0148,
#        6.9958,
#        2.1628,
#        6.2079,
#        2.1628],
#       'span': {'offset': 317, 'length': 9},
#       'confidence': 0.993},
#      {'content': 'CORPORATION',
#       'polygon': [7.0292,
#        2.0148,
#        7.9652,
#        2.0148,
#        7.9652,
#        2.1628,
#        7.0244,
#        2.1628],
#       'span': {'offset': 327, 'length': 11},
#       'confidence': 0.993},
#      {'content': 'SERVICE',
#       'polygon': [5.1573,
#        2.2153,
#        5.6921,
#        2.2153,
#        5.6969,
#        2.3681,
#        5.1573,
#        2.3633],
#       'span': {'offset': 339, 'length': 7},
#       'confidence': 0.995},
#      {'content': 'PERIOD:',
#       'polygon': [5.7256,
#        2.2153,
#        6.2938,
#        2.2153,
#        6.2986,
#        2.3681,
#        5.7256,
#        2.3681],
#       'span': {'offset': 347, 'length': 7},
#       'confidence': 0.993},
#      {'content': '10/14/2019',
#       'polygon': [6.3225,
#        2.2153,
#        7.077,
#        2.2153,
#        7.077,
#        2.3681,
#        6.3272,
#        2.3681],
#       'span': {'offset': 355, 'length': 10},
#       'confidence': 0.994},
#      {'content': '-',
#       'polygon': [7.1056,
#        2.2153,
#        7.1868,
#        2.2153,
#        7.1916,
#        2.3681,
#        7.1104,
#        2.3681],
#       'span': {'offset': 366, 'length': 1},
#       'confidence': 0.995},
#      {'content': '11/14/2019',
#       'polygon': [7.2489,
#        2.2153,
#        7.9986,
#        2.2153,
#        8.0034,
#        2.3681,
#        7.2489,
#        2.3681],
#       'span': {'offset': 368, 'length': 10},
#       'confidence': 0.961},
#      {'content': 'CUSTOMER',
#       'polygon': [6.3177,
#        2.4253,
#        7.0483,
#        2.4253,
#        7.0483,
#        2.5734,
#        6.3177,
#        2.5734],
#       'span': {'offset': 379, 'length': 8},
#       'confidence': 0.995},
#      {'content': 'ID:',
#       'polygon': [7.0865,
#        2.4253,
#        7.2919,
#        2.4253,
#        7.2919,
#        2.5734,
#        7.0865,
#        2.5734],
#       'span': {'offset': 388, 'length': 3},
#       'confidence': 0.995},
#      {'content': 'CID-12345',
#       'polygon': [7.3205,
#        2.4253,
#        8.0034,
#        2.4206,
#        7.9986,
#        2.5734,
#        7.3205,
#        2.5734],
#       'span': {'offset': 392, 'length': 9},
#       'confidence': 0.992},
#      {'content': 'SERVICE',
#       'polygon': [6.1888,
#        3.5282,
#        6.7427,
#        3.5282,
#        6.7427,
#        3.6905,
#        6.1888,
#        3.6905],
#       'span': {'offset': 402, 'length': 7},
#       'confidence': 0.961},
#      {'content': 'ADDRESS:',
#       'polygon': [6.7713,
#        3.5282,
#        7.4303,
#        3.5282,
#        7.4351,
#        3.6905,
#        6.7761,
#        3.6905],
#       'span': {'offset': 410, 'length': 8},
#       'confidence': 0.989},
#      {'content': 'Microsoft',
#       'polygon': [6.1983,
#        3.7478,
#        6.8621,
#        3.7478,
#        6.8669,
#        3.9006,
#        6.1983,
#        3.9054],
#       'span': {'offset': 419, 'length': 9},
#       'confidence': 0.989},
#      {'content': 'Services',
#       'polygon': [6.8955,
#        3.7478,
#        7.4542,
#        3.7478,
#        7.4542,
#        3.9054,
#        6.8955,
#        3.9006],
#       'span': {'offset': 429, 'length': 8},
#       'confidence': 0.994},
#      {'content': '123',
#       'polygon': [6.2126,
#        3.9531,
#        6.4419,
#        3.9531,
#        6.4419,
#        4.1155,
#        6.2126,
#        4.1107],
#       'span': {'offset': 438, 'length': 3},
#       'confidence': 0.997},
#      {'content': 'Service',
#       'polygon': [6.4848,
#        3.9531,
#        6.9719,
#        3.9579,
#        6.9719,
#        4.1107,
#        6.4848,
#        4.1155],
#       'span': {'offset': 442, 'length': 7},
#       'confidence': 0.995},
#      {'content': 'St,',
#       'polygon': [7.0149,
#        3.9579,
#        7.1868,
#        3.9627,
#        7.1868,
#        4.1059,
#        7.0101,
#        4.1107],
#       'span': {'offset': 450, 'length': 3},
#       'confidence': 0.995},
#      {'content': 'Redmond',
#       'polygon': [6.1935,
#        4.1536,
#        6.843,
#        4.1536,
#        6.8478,
#        4.316,
#        6.1983,
#        4.3064],
#       'span': {'offset': 454, 'length': 7},
#       'confidence': 0.995},
#      {'content': 'WA,',
#       'polygon': [6.8955, 4.1536, 7.182, 4.1489, 7.1868, 4.316, 6.9003, 4.316],
#       'span': {'offset': 462, 'length': 3},
#       'confidence': 0.995},
#      {'content': '98052',
#       'polygon': [7.2154, 4.1489, 7.6452, 4.1441, 7.65, 4.316, 7.2202, 4.316],
#       'span': {'offset': 466, 'length': 5},
#       'confidence': 0.995},
#      {'content': 'SALESPERSON',
#       'polygon': [0.6876,
#        4.6263,
#        1.5854,
#        4.6359,
#        1.5854,
#        4.7695,
#        0.6876,
#        4.7791],
#       'span': {'offset': 472, 'length': 11},
#       'confidence': 0.993},
#      {'content': 'P.O.',
#       'polygon': [2.1059,
#        4.6311,
#        2.3876,
#        4.6263,
#        2.3876,
#        4.7695,
#        2.1107,
#        4.7695],
#       'span': {'offset': 484, 'length': 4},
#       'confidence': 0.992},
#      {'content': 'NUMBER',
#       'polygon': [2.4115,
#        4.6263,
#        3.0084,
#        4.6311,
#        3.0084,
#        4.7695,
#        2.4163,
#        4.7695],
#       'span': {'offset': 489, 'length': 6},
#       'confidence': 0.995},
#      {'content': 'REQUISITIONER',
#       'polygon': [3.4716,
#        4.6263,
#        4.5126,
#        4.6263,
#        4.5126,
#        4.7791,
#        3.4764,
#        4.7743],
#       'span': {'offset': 496, 'length': 13},
#       'confidence': 0.993},
#      {'content': 'SHIPPED',
#       'polygon': [4.7992,
#        4.6311,
#        5.3388,
#        4.6311,
#        5.3435,
#        4.7695,
#        4.8039,
#        4.7695],
#       'span': {'offset': 510, 'length': 7},
#       'confidence': 0.995},
#      {'content': 'VIA',
#       'polygon': [5.4056,
#        4.6311,
#        5.611,
#        4.6311,
#        5.611,
#        4.7695,
#        5.4056,
#        4.7695],
#       'span': {'offset': 518, 'length': 3},
#       'confidence': 0.996},
#      {'content': 'F.O.B.',
#       'polygon': [5.8497,
#        4.6359,
#        6.2556,
#        4.6311,
#        6.2604,
#        4.7695,
#        5.8497,
#        4.7695],
#       'span': {'offset': 522, 'length': 6},
#       'confidence': 0.993},
#      {'content': 'POINT',
#       'polygon': [6.2843,
#        4.6311,
#        6.7045,
#        4.6263,
#        6.7045,
#        4.7743,
#        6.2843,
#        4.7743],
#       'span': {'offset': 529, 'length': 5},
#       'confidence': 0.993},
#      {'content': 'TERMS',
#       'polygon': [7.1772,
#        4.6359,
#        7.6309,
#        4.6311,
#        7.6309,
#        4.7695,
#        7.182,
#        4.7648],
#       'span': {'offset': 535, 'length': 5},
#       'confidence': 0.994},
#      {'content': 'PO-3333',
#       'polygon': [1.8862,
#        4.9128,
#        2.4784,
#        4.9032,
#        2.4784,
#        5.056,
#        1.8862,
#        5.056],
#       'span': {'offset': 541, 'length': 7},
#       'confidence': 0.961},
#      {'content': 'DATE',
#       'polygon': [0.7258,
#        5.4045,
#        1.0744,
#        5.3997,
#        1.0744,
#        5.5286,
#        0.7258,
#        5.5334],
#       'span': {'offset': 549, 'length': 4},
#       'confidence': 0.993},
#      {'content': 'ITEM',
#       'polygon': [1.3944,
#        5.3997,
#        1.6713,
#        5.3997,
#        1.6713,
#        5.5382,
#        1.3944,
#        5.5382],
#       'span': {'offset': 554, 'length': 4},
#       'confidence': 0.991},
#      {'content': 'CODE',
#       'polygon': [1.7812,
#        5.3997,
#        2.1441,
#        5.3997,
#        2.1441,
#        5.5382,
#        1.7812,
#        5.5382],
#       'span': {'offset': 559, 'length': 4},
#       'confidence': 0.982},
#      {'content': 'DESCRIPTION',
#       'polygon': [2.8365,
#        5.3997,
#        3.6865,
#        5.3997,
#        3.6865,
#        5.5382,
#        2.8365,
#        5.5382],
#       'span': {'offset': 564, 'length': 11},
#       'confidence': 0.993},
#      {'content': 'QTY',
#       'polygon': [4.3933,
#        5.4045,
#        4.6607,
#        5.4045,
#        4.6607,
#        5.5382,
#        4.3933,
#        5.5382],
#       'span': {'offset': 576, 'length': 3},
#       'confidence': 0.995},
#      {'content': 'UM',
#       'polygon': [5.0331,
#        5.3997,
#        5.2051,
#        5.3997,
#        5.2051,
#        5.5334,
#        5.0331,
#        5.5286],
#       'span': {'offset': 580, 'length': 2},
#       'confidence': 0.995},
#      {'content': 'PRICE',
#       'polygon': [5.8402,
#        5.4045,
#        6.2222,
#        5.3997,
#        6.2222,
#        5.5334,
#        5.8449,
#        5.5286],
#       'span': {'offset': 583, 'length': 5},
#       'confidence': 0.926},
#      {'content': 'TAX',
#       'polygon': [6.7236,
#        5.4045,
#        6.9624,
#        5.4045,
#        6.9624,
#        5.5286,
#        6.7236,
#        5.5286],
#       'span': {'offset': 589, 'length': 3},
#       'confidence': 0.996},
#      {'content': 'AMOUNT',
#       'polygon': [7.2823,
#        5.4045,
#        7.9031,
#        5.395,
#        7.9031,
#        5.543,
#        7.2871,
#        5.5334],
#       'span': {'offset': 593, 'length': 6},
#       'confidence': 0.995},
#      {'content': '3/4/2021',
#       'polygon': [0.573, 5.6671, 1.2177, 5.6623, 1.2177, 5.8342, 0.573, 5.839],
#       'span': {'offset': 600, 'length': 8},
#       'confidence': 0.995},
#      {'content': 'A123',
#       'polygon': [1.6045,
#        5.6719,
#        1.9435,
#        5.6719,
#        1.9435,
#        5.8151,
#        1.5997,
#        5.8151],
#       'span': {'offset': 609, 'length': 4},
#       'confidence': 0.993},
#      {'content': 'Consulting',
#       'polygon': [2.3256,
#        5.6719,
#        3.0514,
#        5.6767,
#        3.0514,
#        5.8342,
#        2.3256,
#        5.839],
#       'span': {'offset': 614, 'length': 10},
#       'confidence': 0.979},
#      {'content': 'Services',
#       'polygon': [3.0848,
#        5.6767,
#        3.634,
#        5.6767,
#        3.6292,
#        5.8294,
#        3.0801,
#        5.8342],
#       'span': {'offset': 625, 'length': 8},
#       'confidence': 0.994},
#      {'content': '2',
#       'polygon': [4.5986,
#        5.6767,
#        4.6607,
#        5.6767,
#        4.6559,
#        5.8056,
#        4.5938,
#        5.8056],
#       'span': {'offset': 634, 'length': 1},
#       'confidence': 0.996},
#      {'content': 'hours',
#       'polygon': [4.8183,
#        5.6767,
#        5.2146,
#        5.6767,
#        5.2146,
#        5.8151,
#        4.8183,
#        5.8151],
#       'span': {'offset': 636, 'length': 5},
#       'confidence': 0.994},
#      {'content': '$30.00',
#       'polygon': [5.9452,
#        5.6623,
#        6.4228,
#        5.6623,
#        6.4228,
#        5.8294,
#        5.9452,
#        5.8294],
#       'span': {'offset': 642, 'length': 6},
#       'confidence': 0.995},
#      {'content': '10%',
#       'polygon': [6.7093,
#        5.6671,
#        7.0053,
#        5.6671,
#        7.0053,
#        5.8247,
#        6.7093,
#        5.8294],
#       'span': {'offset': 649, 'length': 3},
#       'confidence': 0.993},
#      {'content': '$60.00',
#       'polygon': [7.4447,
#        5.6671,
#        7.9174,
#        5.6671,
#        7.9174,
#        5.8294,
#        7.4447,
#        5.8294],
#       'span': {'offset': 653, 'length': 6},
#       'confidence': 0.995},
#      {'content': '3/5/2021',
#       'polygon': [0.5778,
#        5.9631,
#        1.2272,
#        5.9583,
#        1.232,
#        6.1254,
#        0.5778,
#        6.1254],
#       'span': {'offset': 660, 'length': 8},
#       'confidence': 0.995},
#      {'content': 'B456',
#       'polygon': [1.6045,
#        5.9727,
#        1.9388,
#        5.9727,
#        1.9388,
#        6.1111,
#        1.6045,
#        6.1111],
#       'span': {'offset': 669, 'length': 4},
#       'confidence': 0.993},
#      {'content': 'Document',
#       'polygon': [2.3256,
#        5.9727,
#        3.0419,
#        5.9774,
#        3.0466,
#        6.1159,
#        2.3256,
#        6.1254],
#       'span': {'offset': 674, 'length': 8},
#       'confidence': 0.992},
#      {'content': 'Fee',
#       'polygon': [3.0705,
#        5.9774,
#        3.3045,
#        5.9774,
#        3.3045,
#        6.1111,
#        3.0705,
#        6.1159],
#       'span': {'offset': 683, 'length': 3},
#       'confidence': 0.996},
#      {'content': '3',
#       'polygon': [4.589,
#        5.9774,
#        4.6559,
#        5.9774,
#        4.6559,
#        6.1016,
#        4.589,
#        6.1016],
#       'span': {'offset': 687, 'length': 1},
#       'confidence': 0.995},
#      {'content': '$10.00',
#       'polygon': [5.9452,
#        5.9583,
#        6.4132,
#        5.9583,
#        6.4132,
#        6.1159,
#        5.95,
#        6.1207],
#       'span': {'offset': 689, 'length': 6},
#       'confidence': 0.993},
#      {'content': '5%',
#       'polygon': [6.7331,
#        5.9727,
#        6.9385,
#        5.9679,
#        6.9385,
#        6.1063,
#        6.7331,
#        6.1111],
#       'span': {'offset': 696, 'length': 2},
#       'confidence': 0.961},
#      {'content': '$30.00',
#       'polygon': [7.4447,
#        5.9679,
#        7.9126,
#        5.9631,
#        7.9126,
#        6.1207,
#        7.4494,
#        6.1207],
#       'span': {'offset': 699, 'length': 6},
#       'confidence': 0.995},
#      {'content': '3/6/2021',
#       'polygon': [0.5778,
#        6.2687,
#        1.2177,
#        6.2639,
#        1.2177,
#        6.4214,
#        0.5778,
#        6.4262],
#       'span': {'offset': 706, 'length': 8},
#       'confidence': 0.99},
#      {'content': 'C789',
#       'polygon': [1.6045,
#        6.2687,
#        1.9388,
#        6.2687,
#        1.9388,
#        6.4167,
#        1.5997,
#        6.4167],
#       'span': {'offset': 715, 'length': 4},
#       'confidence': 0.992},
#      {'content': 'Printing',
#       'polygon': [2.3208,
#        6.2734,
#        2.8508,
#        6.2734,
#        2.8508,
#        6.4405,
#        2.316,
#        6.4358],
#       'span': {'offset': 720, 'length': 8},
#       'confidence': 0.994},
#      {'content': 'Fee',
#       'polygon': [2.8843,
#        6.2734,
#        3.1326,
#        6.2734,
#        3.1374,
#        6.4358,
#        2.8843,
#        6.4405],
#       'span': {'offset': 729, 'length': 3},
#       'confidence': 0.994},
#      {'content': '10',
#       'polygon': [4.5126,
#        6.2734,
#        4.6511,
#        6.2734,
#        4.6511,
#        6.4119,
#        4.5126,
#        6.4119],
#       'span': {'offset': 733, 'length': 2},
#       'confidence': 0.998},
#      {'content': 'pages',
#       'polygon': [4.8183,
#        6.283,
#        5.2289,
#        6.283,
#        5.2289,
#        6.4453,
#        4.8183,
#        6.4453],
#       'span': {'offset': 736, 'length': 5},
#       'confidence': 0.991},
#      {'content': '$1.00',
#       'polygon': [6.0312,
#        6.2543,
#        6.418,
#        6.2543,
#        6.418,
#        6.4167,
#        6.0312,
#        6.4214],
#       'span': {'offset': 742, 'length': 5},
#       'confidence': 0.995},
#      {'content': '20%',
#       'polygon': [6.6997,
#        6.2591,
#        6.991,
#        6.2591,
#        6.991,
#        6.4262,
#        6.6949,
#        6.4262],
#       'span': {'offset': 748, 'length': 3},
#       'confidence': 0.995},
#      {'content': '$10.00',
#       'polygon': [7.4399,
#        6.2687,
#        7.9126,
#        6.2639,
#        7.9126,
#        6.4214,
#        7.4447,
#        6.4214],
#       'span': {'offset': 752, 'length': 6},
#       'confidence': 0.993},
#      {'content': 'SUBTOTAL',
#       'polygon': [6.0169,
#        6.8845,
#        6.7284,
#        6.8893,
#        6.7284,
#        7.0421,
#        6.0169,
#        7.0421],
#       'span': {'offset': 759, 'length': 8},
#       'confidence': 0.994},
#      {'content': '$100.00',
#       'polygon': [7.3635,
#        6.8559,
#        7.9174,
#        6.8511,
#        7.9222,
#        7.0182,
#        7.3683,
#        7.0182],
#       'span': {'offset': 768, 'length': 7},
#       'confidence': 0.995},
#      {'content': 'SALES',
#       'polygon': [6.0216,
#        7.171,
#        6.4323,
#        7.171,
#        6.4323,
#        7.3429,
#        6.0216,
#        7.3429],
#       'span': {'offset': 776, 'length': 5},
#       'confidence': 0.994},
#      {'content': 'TAX',
#       'polygon': [6.4657,
#        7.171,
#        6.7331,
#        7.171,
#        6.7379,
#        7.3429,
#        6.4705,
#        7.3429],
#       'span': {'offset': 782, 'length': 3},
#       'confidence': 0.994},
#      {'content': '$10.00',
#       'polygon': [7.4542,
#        7.1519,
#        7.9174,
#        7.1519,
#        7.9174,
#        7.3142,
#        7.4542,
#        7.319],
#       'span': {'offset': 786, 'length': 6},
#       'confidence': 0.994},
#      {'content': 'TOTAL',
#       'polygon': [6.2986,
#        7.4861,
#        6.7331,
#        7.4909,
#        6.7331,
#        7.6437,
#        6.3034,
#        7.6341],
#       'span': {'offset': 793, 'length': 5},
#       'confidence': 0.995},
#      {'content': '$110.00',
#       'polygon': [7.3683,
#        7.4575,
#        7.9079,
#        7.4527,
#        7.9126,
#        7.6198,
#        7.3683,
#        7.6246],
#       'span': {'offset': 799, 'length': 7},
#       'confidence': 0.995},
#      {'content': 'PREVIOUS',
#       'polygon': [4.7848,
#        7.7773,
#        5.482,
#        7.7773,
#        5.482,
#        7.9397,
#        4.7848,
#        7.9349],
#       'span': {'offset': 807, 'length': 8},
#       'confidence': 0.981},
#      {'content': 'UNPAID',
#       'polygon': [5.5154,
#        7.7773,
#        6.0455,
#        7.7773,
#        6.0455,
#        7.9397,
#        5.5154,
#        7.9397],
#       'span': {'offset': 816, 'length': 6},
#       'confidence': 0.994},
#      {'content': 'BALANCE',
#       'polygon': [6.098,
#        7.7773,
#        6.7331,
#        7.7821,
#        6.7331,
#        7.9301,
#        6.098,
#        7.9349],
#       'span': {'offset': 823, 'length': 7},
#       'confidence': 0.992},
#      {'content': '$500.00',
#       'polygon': [7.3635,
#        7.7535,
#        7.9126,
#        7.7535,
#        7.9126,
#        7.911,
#        7.3635,
#        7.9158],
#       'span': {'offset': 831, 'length': 7},
#       'confidence': 0.995},
#      {'content': 'AMOUNT',
#       'polygon': [5.759,
#        8.0686,
#        6.4084,
#        8.0781,
#        6.4084,
#        8.2261,
#        5.759,
#        8.2309],
#       'span': {'offset': 839, 'length': 6},
#       'confidence': 0.995},
#      {'content': 'DUE',
#       'polygon': [6.4371,
#        8.0781,
#        6.7236,
#        8.0781,
#        6.7236,
#        8.2261,
#        6.4371,
#        8.2261],
#       'span': {'offset': 846, 'length': 3},
#       'confidence': 0.996},
#      {'content': '$610.00',
#       'polygon': [7.3635,
#        8.0447,
#        7.9222,
#        8.0495,
#        7.927,
#        8.2118,
#        7.3635,
#        8.2166],
#       'span': {'offset': 850, 'length': 7},
#       'confidence': 0.972},
#      {'content': 'THANK',
#       'polygon': [3.1278,
#        8.5174,
#        3.5671,
#        8.5126,
#        3.5719,
#        8.6701,
#        3.1326,
#        8.6654],
#       'span': {'offset': 858, 'length': 5},
#       'confidence': 0.995},
#      {'content': 'YOU',
#       'polygon': [3.6197,
#        8.5126,
#        3.8966,
#        8.5126,
#        3.8966,
#        8.6749,
#        3.6244,
#        8.6701],
#       'span': {'offset': 864, 'length': 3},
#       'confidence': 0.997},
#      {'content': 'FOR',
#       'polygon': [3.9348,
#        8.5126,
#        4.2118,
#        8.5078,
#        4.2118,
#        8.6749,
#        3.9396,
#        8.6749],
#       'span': {'offset': 868, 'length': 3},
#       'confidence': 0.994},
#      {'content': 'YOUR',
#       'polygon': [4.25,
#        8.5078,
#        4.6177,
#        8.5078,
#        4.6225,
#        8.6749,
#        4.2548,
#        8.6749],
# ...
#          5.1057,
#          0.5135,
#          5.1134]}],
#       'spans': []},
#      {'kind': 'content',
#       'rowIndex': 1,
#       'columnIndex': 1,
#       'rowSpan': 1,
#       'columnSpan': 1,
#       'content': 'PO-3333',
#       'boundingRegions': [{'pageNumber': 1,
#         'polygon': [1.8202,
#          4.836,
#          3.3047,
#          4.836,
#          3.3047,
#          5.1057,
#          1.8124,
#          5.1057]}],
#       'spans': [{'offset': 541, 'length': 7}]},
#      {'kind': 'content',
#       'rowIndex': 1,
#       'columnIndex': 2,
#       'rowSpan': 1,
#       'columnSpan': 1,
#       'content': '',
#       'boundingRegions': [{'pageNumber': 1,
#         'polygon': [3.3047,
#          4.836,
#          4.6964,
#          4.836,
#          4.6964,
#          5.1134,
#          3.3047,
#          5.1057]}],
#       'spans': []},
#      {'kind': 'content',
#       'rowIndex': 1,
#       'columnIndex': 3,
#       'rowSpan': 1,
#       'columnSpan': 1,
#       'content': '',
#       'boundingRegions': [{'pageNumber': 1,
#         'polygon': [4.6964,
#          4.836,
#          5.7402,
#          4.836,
#          5.7402,
#          5.1134,
#          4.6964,
#          5.1134]}],
#       'spans': []},
#      {'kind': 'content',
#       'rowIndex': 1,
#       'columnIndex': 4,
#       'rowSpan': 1,
#       'columnSpan': 1,
#       'content': '',
#       'boundingRegions': [{'pageNumber': 1,
#         'polygon': [5.7402,
#          4.836,
#          6.8072,
#          4.836,
#          6.8072,
#          5.1134,
#          5.7402,
#          5.1134]}],
#       'spans': []},
#      {'kind': 'content',
#       'rowIndex': 1,
#       'columnIndex': 5,
#       'rowSpan': 1,
#       'columnSpan': 1,
#       'content': '',
#       'boundingRegions': [{'pageNumber': 1,
#         'polygon': [6.8072,
#          4.836,
#          7.9902,
#          4.836,
#          7.9902,
#          5.1134,
#          6.8072,
#          5.1134]}],
#       'spans': []}],
#     'boundingRegions': [{'pageNumber': 1,
#       'polygon': [0.4693,
#        4.547,
#        8.0061,
#        4.5467,
#        8.0058,
#        5.1205,
#        0.4686,
#        5.1213]}],
#     'spans': [{'offset': 472, 'length': 76}]},
#    {'rowCount': 4,
#     'columnCount': 8,
#     'cells': [{'kind': 'columnHeader',
#       'rowIndex': 0,
#       'columnIndex': 0,
#       'rowSpan': 1,
#       'columnSpan': 1,
#       'content': 'DATE',
#       'boundingRegions': [{'pageNumber': 1,
#         'polygon': [0.4992,
#          5.321,
#          1.3091,
#          5.3287,
#          1.3091,
#          5.6057,
#          0.4992,
#          5.6057]}],
#       'spans': [{'offset': 549, 'length': 4}]},
#      {'kind': 'columnHeader',
#       'rowIndex': 0,
#       'columnIndex': 1,
#       'rowSpan': 1,
#       'columnSpan': 1,
#       'content': 'ITEM CODE',
#       'boundingRegions': [{'pageNumber': 1,
#         'polygon': [1.3091,
#          5.3287,
#          2.2424,
#          5.3287,
#          2.2424,
#          5.6057,
#          1.3091,
#          5.6057]}],
#       'spans': [{'offset': 554, 'length': 9}]},
#      {'kind': 'columnHeader',
#       'rowIndex': 0,
#       'columnIndex': 2,
#       'rowSpan': 1,
#       'columnSpan': 1,
#       'content': 'DESCRIPTION',
#       'boundingRegions': [{'pageNumber': 1,
#         'polygon': [2.2424,
#          5.3287,
#          4.3172,
#          5.3287,
#          4.3172,
#          5.6057,
#          2.2424,
#          5.6057]}],
#       'spans': [{'offset': 564, 'length': 11}]},
#      {'kind': 'columnHeader',
#       'rowIndex': 0,
#       'columnIndex': 3,
#       'rowSpan': 1,
#       'columnSpan': 1,
#       'content': 'QTY',
#       'boundingRegions': [{'pageNumber': 1,
#         'polygon': [4.3172,
#          5.3287,
#          4.7491,
#          5.3287,
#          4.7491,
#          5.6057,
#          4.3172,
#          5.6057]}],
#       'spans': [{'offset': 576, 'length': 3}]},
#      {'kind': 'columnHeader',
#       'rowIndex': 0,
#       'columnIndex': 4,
#       'rowSpan': 1,
#       'columnSpan': 1,
#       'content': 'UM',
#       'boundingRegions': [{'pageNumber': 1,
#         'polygon': [4.7491,
#          5.3287,
#          5.559,
#          5.3287,
#          5.559,
#          5.6057,
#          4.7491,
#          5.6057]}],
#       'spans': [{'offset': 580, 'length': 2}]},
#      {'kind': 'columnHeader',
#       'rowIndex': 0,
#       'columnIndex': 5,
#       'rowSpan': 1,
#       'columnSpan': 1,
#       'content': 'PRICE',
#       'boundingRegions': [{'pageNumber': 1,
#         'polygon': [5.559, 5.3287, 6.5, 5.3287, 6.5, 5.6057, 5.559, 5.6057]}],
#       'spans': [{'offset': 583, 'length': 5}]},
#      {'kind': 'columnHeader',
#       'rowIndex': 0,
#       'columnIndex': 6,
#       'rowSpan': 1,
#       'columnSpan': 1,
#       'content': 'TAX',
#       'boundingRegions': [{'pageNumber': 1,
#         'polygon': [6.5,
#          5.3287,
#          7.1865,
#          5.3287,
#          7.1865,
#          5.6057,
#          6.5,
#          5.6057]}],
#       'spans': [{'offset': 589, 'length': 3}]},
#      {'kind': 'columnHeader',
#       'rowIndex': 0,
#       'columnIndex': 7,
#       'rowSpan': 1,
#       'columnSpan': 1,
#       'content': 'AMOUNT',
#       'boundingRegions': [{'pageNumber': 1,
#         'polygon': [7.1865,
#          5.3287,
#          7.9964,
#          5.3287,
#          7.9964,
#          5.6057,
#          7.1865,
#          5.6057]}],
#       'spans': [{'offset': 593, 'length': 6}]},
#      {'kind': 'content',
#       'rowIndex': 1,
#       'columnIndex': 0,
#       'rowSpan': 1,
#       'columnSpan': 1,
#       'content': '3/4/2021',
#       'boundingRegions': [{'pageNumber': 1,
#         'polygon': [0.4992,
#          5.6057,
#          1.3091,
#          5.6057,
#          1.3091,
#          5.898,
#          0.4992,
#          5.898]}],
#       'spans': [{'offset': 600, 'length': 8}]},
#      {'kind': 'content',
#       'rowIndex': 1,
#       'columnIndex': 1,
#       'rowSpan': 1,
#       'columnSpan': 1,
#       'content': 'A123',
#       'boundingRegions': [{'pageNumber': 1,
#         'polygon': [1.3091,
#          5.6057,
#          2.2424,
#          5.6057,
#          2.2424,
#          5.898,
#          1.3091,
#          5.898]}],
#       'spans': [{'offset': 609, 'length': 4}]},
#      {'kind': 'content',
#       'rowIndex': 1,
#       'columnIndex': 2,
#       'rowSpan': 1,
#       'columnSpan': 1,
#       'content': 'Consulting Services',
#       'boundingRegions': [{'pageNumber': 1,
#         'polygon': [2.2424,
#          5.6057,
#          4.3172,
#          5.6057,
#          4.3172,
#          5.898,
#          2.2424,
#          5.898]}],
#       'spans': [{'offset': 614, 'length': 19}]},
#      {'kind': 'content',
#       'rowIndex': 1,
#       'columnIndex': 3,
#       'rowSpan': 1,
#       'columnSpan': 1,
#       'content': '2',
#       'boundingRegions': [{'pageNumber': 1,
#         'polygon': [4.3172,
#          5.6057,
#          4.7491,
#          5.6057,
#          4.7491,
#          5.898,
#          4.3172,
#          5.898]}],
#       'spans': [{'offset': 634, 'length': 1}]},
#      {'kind': 'content',
#       'rowIndex': 1,
#       'columnIndex': 4,
#       'rowSpan': 1,
#       'columnSpan': 1,
#       'content': 'hours',
#       'boundingRegions': [{'pageNumber': 1,
#         'polygon': [4.7491,
#          5.6057,
#          5.559,
#          5.6057,
#          5.559,
#          5.898,
#          4.7491,
#          5.898]}],
#       'spans': [{'offset': 636, 'length': 5}]},
#      {'kind': 'content',
#       'rowIndex': 1,
#       'columnIndex': 5,
#       'rowSpan': 1,
#       'columnSpan': 1,
#       'content': '$30.00',
#       'boundingRegions': [{'pageNumber': 1,
#         'polygon': [5.559, 5.6057, 6.5, 5.6057, 6.5, 5.898, 5.559, 5.898]}],
#       'spans': [{'offset': 642, 'length': 6}]},
#      {'kind': 'content',
#       'rowIndex': 1,
#       'columnIndex': 6,
#       'rowSpan': 1,
#       'columnSpan': 1,
#       'content': '10%',
#       'boundingRegions': [{'pageNumber': 1,
#         'polygon': [6.5, 5.6057, 7.1865, 5.6057, 7.1942, 5.898, 6.5, 5.898]}],
#       'spans': [{'offset': 649, 'length': 3}]},
#      {'kind': 'content',
#       'rowIndex': 1,
#       'columnIndex': 7,
#       'rowSpan': 1,
#       'columnSpan': 1,
#       'content': '$60.00',
#       'boundingRegions': [{'pageNumber': 1,
#         'polygon': [7.1865,
#          5.6057,
#          7.9964,
#          5.6057,
#          7.9964,
#          5.9057,
#          7.1942,
#          5.898]}],
#       'spans': [{'offset': 653, 'length': 6}]},
#      {'kind': 'content',
#       'rowIndex': 2,
#       'columnIndex': 0,
#       'rowSpan': 1,
#       'columnSpan': 1,
#       'content': '3/5/2021',
#       'boundingRegions': [{'pageNumber': 1,
#         'polygon': [0.4992,
#          5.898,
#          1.3091,
#          5.898,
#          1.3091,
#          6.1903,
#          0.4992,
#          6.1903]}],
#       'spans': [{'offset': 660, 'length': 8}]},
#      {'kind': 'content',
#       'rowIndex': 2,
#       'columnIndex': 1,
#       'rowSpan': 1,
#       'columnSpan': 1,
#       'content': 'B456',
#       'boundingRegions': [{'pageNumber': 1,
#         'polygon': [1.3091,
#          5.898,
#          2.2424,
#          5.898,
#          2.2424,
#          6.1903,
#          1.3091,
#          6.1903]}],
#       'spans': [{'offset': 669, 'length': 4}]},
#      {'kind': 'content',
#       'rowIndex': 2,
#       'columnIndex': 2,
#       'rowSpan': 1,
#       'columnSpan': 1,
#       'content': 'Document Fee',
#       'boundingRegions': [{'pageNumber': 1,
#         'polygon': [2.2424,
#          5.898,
#          4.3172,
#          5.898,
#          4.3172,
#          6.1903,
#          2.2424,
#          6.1903]}],
#       'spans': [{'offset': 674, 'length': 12}]},
#      {'kind': 'content',
#       'rowIndex': 2,
#       'columnIndex': 3,
#       'rowSpan': 1,
#       'columnSpan': 1,
#       'content': '3',
#       'boundingRegions': [{'pageNumber': 1,
#         'polygon': [4.3172,
#          5.898,
#          4.7491,
#          5.898,
#          4.7491,
#          6.1903,
#          4.3172,
#          6.1903]}],
#       'spans': [{'offset': 687, 'length': 1}]},
#      {'kind': 'content',
#       'rowIndex': 2,
#       'columnIndex': 4,
#       'rowSpan': 1,
#       'columnSpan': 1,
#       'content': '',
#       'boundingRegions': [{'pageNumber': 1,
#         'polygon': [4.7491,
#          5.898,
#          5.559,
#          5.898,
#          5.5667,
#          6.1903,
#          4.7491,
#          6.1903]}],
#       'spans': []},
#      {'kind': 'content',
#       'rowIndex': 2,
#       'columnIndex': 5,
#       'rowSpan': 1,
#       'columnSpan': 1,
#       'content': '$10.00',
#       'boundingRegions': [{'pageNumber': 1,
#         'polygon': [5.559, 5.898, 6.5, 5.898, 6.5, 6.1903, 5.5667, 6.1903]}],
#       'spans': [{'offset': 689, 'length': 6}]},
#      {'kind': 'content',
#       'rowIndex': 2,
#       'columnIndex': 6,
#       'rowSpan': 1,
#       'columnSpan': 1,
#       'content': '5%',
#       'boundingRegions': [{'pageNumber': 1,
#         'polygon': [6.5, 5.898, 7.1942, 5.898, 7.1942, 6.1903, 6.5, 6.1903]}],
#       'spans': [{'offset': 696, 'length': 2}]},
#      {'kind': 'content',
#       'rowIndex': 2,
#       'columnIndex': 7,
#       'rowSpan': 1,
#       'columnSpan': 1,
#       'content': '$30.00',
#       'boundingRegions': [{'pageNumber': 1,
#         'polygon': [7.1942,
#          5.898,
#          7.9964,
#          5.9057,
#          7.9964,
#          6.198,
#          7.1942,
#          6.1903]}],
#       'spans': [{'offset': 699, 'length': 6}]},
#      {'kind': 'content',
#       'rowIndex': 3,
#       'columnIndex': 0,
#       'rowSpan': 1,
#       'columnSpan': 1,
#       'content': '3/6/2021',
#       'boundingRegions': [{'pageNumber': 1,
#         'polygon': [0.4992,
#          6.1903,
#          1.3091,
#          6.1903,
#          1.3091,
#          6.4981,
#          0.4992,
#          6.4904]}],
#       'spans': [{'offset': 706, 'length': 8}]},
#      {'kind': 'content',
#       'rowIndex': 3,
#       'columnIndex': 1,
#       'rowSpan': 1,
#       'columnSpan': 1,
#       'content': 'C789',
#       'boundingRegions': [{'pageNumber': 1,
#         'polygon': [1.3091,
#          6.1903,
#          2.2424,
#          6.1903,
#          2.2424,
#          6.4981,
#          1.3091,
#          6.4981]}],
#       'spans': [{'offset': 715, 'length': 4}]},
#      {'kind': 'content',
#       'rowIndex': 3,
#       'columnIndex': 2,
#       'rowSpan': 1,
#       'columnSpan': 1,
#       'content': 'Printing Fee',
#       'boundingRegions': [{'pageNumber': 1,
#         'polygon': [2.2424,
#          6.1903,
#          4.3172,
#          6.1903,
#          4.3172,
#          6.4981,
#          2.2424,
#          6.4981]}],
#       'spans': [{'offset': 720, 'length': 12}]},
#      {'kind': 'content',
#       'rowIndex': 3,
#       'columnIndex': 3,
#       'rowSpan': 1,
#       'columnSpan': 1,
#       'content': '10',
#       'boundingRegions': [{'pageNumber': 1,
#         'polygon': [4.3172,
#          6.1903,
#          4.7491,
#          6.1903,
#          4.7491,
#          6.4981,
#          4.3172,
#          6.4981]}],
#       'spans': [{'offset': 733, 'length': 2}]},
#      {'kind': 'content',
#       'rowIndex': 3,
#       'columnIndex': 4,
#       'rowSpan': 1,
#       'columnSpan': 1,
#       'content': 'pages',
#       'boundingRegions': [{'pageNumber': 1,
#         'polygon': [4.7491,
#          6.1903,
#          5.5667,
#          6.1903,
#          5.5667,
#          6.4981,
#          4.7491,
#          6.4981]}],
#       'spans': [{'offset': 736, 'length': 5}]},
#      {'kind': 'content',
#       'rowIndex': 3,
#       'columnIndex': 5,
#       'rowSpan': 1,
#       'columnSpan': 1,
#       'content': '$1.00',
#       'boundingRegions': [{'pageNumber': 1,
#         'polygon': [5.5667,
#          6.1903,
#          6.5,
#          6.1903,
#          6.5,
#          6.4981,
#          5.5667,
#          6.4981]}],
#       'spans': [{'offset': 742, 'length': 5}]},
#      {'kind': 'content',
#       'rowIndex': 3,
#       'columnIndex': 6,
#       'rowSpan': 1,
#       'columnSpan': 1,
#       'content': '20%',
#       'boundingRegions': [{'pageNumber': 1,
#         'polygon': [6.5,
#          6.1903,
#          7.1942,
#          6.1903,
#          7.1942,
#          6.4981,
#          6.5,
#          6.4981]}],
#       'spans': [{'offset': 748, 'length': 3}]},
#      {'kind': 'content',
#       'rowIndex': 3,
#       'columnIndex': 7,
#       'rowSpan': 1,
#       'columnSpan': 1,
#       'content': '$10.00',
#       'boundingRegions': [{'pageNumber': 1,
#         'polygon': [7.1942,
#          6.1903,
#          7.9964,
#          6.198,
#          7.9964,
#          6.4981,
#          7.1942,
#          6.4981]}],
#       'spans': [{'offset': 752, 'length': 6}]}],
#     'boundingRegions': [{'pageNumber': 1,
#       'polygon': [0.4782,
#        5.3264,
#        8.0003,
#        5.3259,
#        7.9986,
#        6.5033,
#        0.4764,
#        6.5041]}],
#     'spans': [{'offset': 549, 'length': 209}]}],
#   'keyValuePairs': [],
#   'styles': [],
#   'documents': [{'docType': 'Contoso',
#     'boundingRegions': [{'pageNumber': 1,
#       'polygon': [0.0, 0.0, 8.5, 0.0, 8.5, 11.0, 0.0, 11.0]}],
#     'spans': [{'offset': 0, 'length': 945}],
#     'fields': {'Vendor': {'valueType': 'string',
#       'value': 'CONTOSO LTD.',
#       'content': 'CONTOSO LTD.',
#       'boundingRegions': [{'pageNumber': 1,
#         'polygon': [0.5778,
#          0.6455,
#          2.3356,
#          0.6493,
#          2.3351,
#          0.899,
#          0.5773,
#          0.8952]}],
#       'spans': [{'offset': 0, 'length': 12}],
#       'confidence': 0.98},
#      'VendorAddress': {'valueType': 'string',
#       'value': 'Contoso Headquarters 123 456th St New York, NY, 10001',
#       'content': 'Contoso Headquarters 123 456th St New York, NY, 10001',
#       'boundingRegions': [{'pageNumber': 1,
#         'polygon': [0.5683,
#          1.3989,
#          2.1059,
#          1.3989,
#          2.1059,
#          1.9813,
#          0.5683,
#          1.9813]}],
#       'spans': [{'offset': 13, 'length': 53}],
#       'confidence': 0.321},
#      'InvoiceNumber': {'valueType': 'string',
#       'value': 'INV-100',
#       'content': 'INV-100',
#       'boundingRegions': [{'pageNumber': 1,
#         'polygon': [7.4685,
#          1.3941,
#          8.0034,
#          1.3941,
#          8.0034,
#          1.5469,
#          7.4685,
#          1.5469]}],
#       'spans': [{'offset': 248, 'length': 7}],
#       'confidence': 0.863},
#      'AmountDue': {'valueType': 'string',
#       'value': '$610.00',
#       'content': '$610.00',
#       'boundingRegions': [{'pageNumber': 1,
#         'polygon': [7.3635,
#          8.0447,
#          7.927,
#          8.0447,
#          7.927,
#          8.2166,
#          7.3635,
#          8.2166]}],
#       'spans': [{'offset': 850, 'length': 7}],
#       'confidence': 0.864}},
#     'confidence': 0.997}]}}

# %%
doc_canvas = DocumentCanvas(working_dir)

canvases = doc_canvas.load_pdf(pdf_path, document_fields_path, pdf_feedback_path)

# %% [markdown]
# ### Display Doc-Intel Results

# %%
for canvas in canvases:
    display(canvas)
# Out:
# BBoxWidget(bboxes=[{'x': 115.56, 'y': 129.1, 'width': 351.56, 'height': 50.70000000000001, 'label': 'Vendor', …
